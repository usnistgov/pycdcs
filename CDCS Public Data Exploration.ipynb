# %% [markdown]
# # CDCS Public Data Exploration
#
# This provides an example of how anonymous users can query records and templates in a CDCS instance without logging in, assuming read permissions have been set to allow it.

# %%
import cdcs
from cdcs import CDCS

print('Notebook executed for cdcs version', cdcs.__version__)
# Out:
# Notebook executed for cdcs version 0.2.3

# %% [markdown]
# Create client manager with anonymous user

# %%
curator = CDCS('https://potentials.nist.gov/', username='')

# %% [markdown]
# See the available record templates

# %%
curator.template_titles
# Out:
# ['Potential',
#  'relaxed_crystal',
#  'FAQ',
#  'Action',
#  'PotentialProperties',
#  'Request',
#  'free_surface',
#  'stacking_fault',
#  'point_defect',
#  'crystal_prototype',
#  'potential_LAMMPS',
#  'Citation',
#  'calculation_diatom_scan',
#  'calculation_isolated_atom',
#  'potential_LAMMPS_KIM',
#  'calculation_bond_angle_scan',
#  'dislocation',
#  'calculation_E_vs_r_scan',
#  'calculation_relax_box',
#  'calculation_relax_dynamic',
#  'calculation_relax_static',
#  'pycdcs-test']

# %% [markdown]
# Query and explore the data
#
# __Notes:__ current design downloads all matching records by iterating through all pages until next=None. Need args for
#
# - limit: max # of items
# - page: allows access of those beyond limit
# - nitems: number retrieved per download (available in rest call?)

# %%
curator.query(template='Potential', keyword='Mishin')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 36/36 [00:02<00:00,  8.90it/s]
#         id  template  workspace user_id  \
# 0   627244        21          1       2
# 1   627471        21          1       2
# 2   627111        21          1       2
# 3   627364        21          1       2
# 4   627088        21          1       2
# 5   627451        21          1       2
# 6   627101        21          1       2
# 7   627704        21          1       2
# 8   627102        21          1       2
# 9   627108        21          1       2
# 10  627602        21          1       2
# 11  627664        21          1       2
# 12  627317        21          1       2
# 13  627682        21          1       2
# 14  627217        21          1       2
# 15  627626        21          1       2
# 16  627455        21          1       2
# 17  627517        21          1       2
# 18  627552        21          1       2
# 19  627593        21          1       2
# 20  627127        21          1       2
# 21  627574        21          1       2
# 22  627605        21          1       2
# 23  627411        21          1       2
# 24  627160        21          1       2
# 25  627499        21          1       2
# 26  627735        21          1       2
# 27  627575        21          1       2
# 28  627589        21          1       2
# 29  627123        21          1       2
# 30  627261        21          1       2
# 31  627497        21          1       2
# 32  627765        21          1       2
# 33  627684        21          1       2
# 34  627151        21          1       2
# 35  627587        21          1       2
#
#                                                 title  \
# 0   potential.1999--Mishin-Y-Farkas-D-Mehl-M-J-Pap...
# 1   potential.2015--Purja-Pun-G-P-Darling-K-A-Kecs...
# 2   potential.2015--Purja-Pun-G-P-Yamakov-V-Mishin...
# 3   potential.2008--Hashibon-A-Lozovoi-A-Y-Mishin-...
# 4            potential.2018--Howells-C-A-Mishin-Y--Cr
# 5   potential.2009--Zhakhovskii-V-V-Inogamov-N-A-P...
# 6   potential.2015--Purja-Pun-G-P-Yamakov-V-Mishin...
# 7   potential.2009--Zhakhovskii-V-V-Inogamov-N-A-P...
# 8   potential.2016--Beland-L-K-Lu-C-Osetskiy-Y-N-e...
# 9   potential.2006--Williams-P-L-Mishin-Y-Hamilton...
# 10          potential.2009--Wu-H-H-Trinkle-D-R--Cu-Ag
# 11  potential.2009--Bonny-G-Pasianot-R-C-Castin-N-...
# 12         potential.1996--Farkas-D-Jones-C--Nb-Ti-Al
<?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 1   <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 2   <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 3   <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 4   <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 5   <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 6   <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 7   <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 8   <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 9   <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 10  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 11  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 12  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 13  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 14  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 15  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 16  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 17  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 18  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 19  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 20  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 21  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 22  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 23  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 24  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 25  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 26  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 27  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 28  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 29  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 30  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 31  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 32  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 33  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 34  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 35  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential

# %% [markdown]
# Same function for both keyword and query calls (which rest url is used is handled underneath).

# %%
records = curator.query(mongoquery={'interatomic-potential.element':'Ga'})
records
# Out:
#        id  template  workspace user_id  \
# 0  627879        21          1       2
# 1  627248        21          1       2
# 2  627439        21          1       2
# 3  627678        21          1       2
# 4  627776        21          1       2
# 5  627649        21          1       2
# 6  627577        21          1       2
# 7  627487        21          1       2
# 8  627771        21          1       2
# 9  627770        21          1       2
#
#                                                title  \
# 0               potential.2012--Belashchenko-D-K--Ga
# 1      potential.2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-N
# 2   potential.2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-In-N
# 3     potential.2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-In
# 4               potential.2006--Bere-A-Serra-A--Ga-N
# 5  potential.2006--Murdick-D-A-Zhou-X-W-Wadley-H-...
# 6  potential.2002--Albe-K-Nordlund-K-Nord-J-Kuron...
# 7  potential.2003--Nord-J-Albe-K-Erhart-P-Nordlun...
# 8          potential.2015--Elliott-R-S-Akerson-A--Ga
# 9  potential.2017--Zhou-X-W-Jones-R-E-Chu-K--In-Ga-N
#
#                      creation_date           last_modification_date  \
# 0 2023-10-31 15:55:54.398000-04:00 2023-10-31 15:55:54.398000-04:00
# 1 2021-08-26 13:14:20.232000-04:00 2022-07-28 15:48:01.580000-04:00
# 2 2021-08-26 13:13:03.653000-04:00 2022-07-28 15:47:10.520000-04:00
# 3 2021-08-26 13:11:05.366000-04:00 2022-07-28 15:45:07.448000-04:00
# 4 2021-08-26 13:14:01.723000-04:00 2022-07-22 18:24:30.642000-04:00
# 5 2021-08-26 13:14:42.650000-04:00 2022-07-22 18:23:41.657000-04:00
# 6 2021-08-26 13:15:08.579000-04:00 2022-07-22 18:23:16.059000-04:00
# 7 2021-08-26 13:15:18.574000-04:00 2022-07-22 18:23:09.939000-04:00
# 8 2021-08-26 13:12:22.444000-04:00 2022-07-22 18:20:05.258000-04:00
# 9 2021-08-26 13:14:50.712000-04:00 2022-07-22 18:18:17.939000-04:00
#
#                   last_change_date  \
# 0 2023-10-31 15:55:57.079000-04:00
# 1 2022-07-28 15:48:01.587000-04:00
# 2 2022-07-28 15:47:10.527000-04:00
# 3 2022-07-28 15:45:07.455000-04:00
# 4 2022-07-22 18:24:31.168000-04:00
# 5 2022-07-22 18:23:42.142000-04:00
# 6 2022-07-22 18:23:16.578000-04:00
# 7 2022-07-22 18:23:10.598000-04:00
# 8 2022-07-22 18:20:05.812000-04:00
# 9 2022-07-22 18:18:18.429000-04:00
#
#                                          xml_content template_title
# 0  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 1  <interatomic-potential  xmlns:xsi="http://www....      Potential
# 2  <interatomic-potential  xmlns:xsi="http://www....      Potential
# 3  <interatomic-potential  xmlns:xsi="http://www....      Potential
# 4  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 5  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 6  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 7  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 8  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 9  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential

# %% [markdown]
# Note that the fetched content is returned as a pandas.DataFrame. This allows for the content to be easily explored and further parsed.

# %%
records.title
# Out:
# 0                 potential.2012--Belashchenko-D-K--Ga
# 1        potential.2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-N
# 2     potential.2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-In-N
# 3       potential.2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-In
# 4                 potential.2006--Bere-A-Serra-A--Ga-N
# 5    potential.2006--Murdick-D-A-Zhou-X-W-Wadley-H-...
# 6    potential.2002--Albe-K-Nordlund-K-Nord-J-Kuron...
# 7    potential.2003--Nord-J-Albe-K-Erhart-P-Nordlun...
# 8            potential.2015--Elliott-R-S-Akerson-A--Ga
# 9    potential.2017--Zhou-X-W-Jones-R-E-Chu-K--In-Ga-N
# Name: title, dtype: object

# %%
records.xml_content[3]
# Out:
# '<interatomic-potential  xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" ><key>f069da69-5d12-4a74-ae7b-6ebe45dd0400</key><id>2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-In</id><URL>https://potentials.nist.gov/pid/rest/local/potentials/potential.2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-In</URL><record-version>2019-05-06</record-version><description><citation><document-type>journal</document-type><title>Atomistic modeling of III-V nitrides: modified embedded-atom method interatomic potentials for GaN, InN and Ga&lt;sub&gt;1-x&lt;/sub&gt;In&lt;sub&gt;x&lt;/sub&gt;N</title><author><given-name>E.C.</given-name><surname>Do</surname></author><author><given-name>Y.-H.</given-name><surname>Shin</surname></author><author><given-name>B.-J.</given-name><surname>Lee</surname></author><publication-name>Journal of Physics: Condensed Matter</publication-name><publication-date><year>2009</year></publication-date><volume>21</volume><issue>32</issue><abstract>Modified embedded-atom method (MEAM) interatomic potentials for the Ga-N and In-N binary and Ga-In-N ternary systems have been developed based on the previously developed potentials for Ga, In and N. The potentials can describe various physical properties (structural, elastic and defect properties) of both zinc-blende and wurtzite-type GaN and InN as well as those of constituent elements, in good agreement with experimental data or high-level calculations. The potential can also describe the structural behavior of Ga&lt;sub&gt;1-x&lt;/sub&gt;In&lt;sub&gt;x&lt;/sub&gt;N ternary nitrides reasonably well. The applicability of the potentials to atomistic investigations of atomic/nanoscale structural evolution in Ga&lt;sub&gt;1-x&lt;/sub&gt;In&lt;sub&gt;x&lt;/sub&gt;N multi-component nitrides during the deposition of constituent element atoms is discussed.</abstract><pages>325801</pages><DOI>10.1088/0953-8984/21/32/325801</DOI><bibtex>@article{Do_2009,\\n abstract = {Modified embedded-atom method (MEAM) interatomic potentials for the Ga-N and In-N binary and Ga-In-N ternary systems have been developed based on the previously developed potentials for Ga, In and N. The potentials can describe various physical properties (structural, elastic and defect properties) of both zinc-blende and wurtzite-type GaN and InN as well as those of constituent elements, in good agreement with experimental data or high-level calculations. The potential can also describe the structural behavior of Ga&lt;sub&gt;1-x&lt;/sub&gt;In&lt;sub&gt;x&lt;/sub&gt;N ternary nitrides reasonably well. The applicability of the potentials to atomistic investigations of atomic/nanoscale structural evolution in Ga&lt;sub&gt;1-x&lt;/sub&gt;In&lt;sub&gt;x&lt;/sub&gt;N multi-component nitrides during the deposition of constituent element atoms is discussed.},\\n author = {Eun Cheol Do and Young-Han Shin and Byeong-Joo Lee},\\n doi = {10.1088/0953-8984/21/32/325801},\\n journal = {Journal of Physics: Condensed Matter},\\n month = {jul},\\n number = {32},\\n pages = {325801},\\n publisher = {IOP Publishing},\\n title = {Atomistic modeling of III-V nitrides: modified embedded-atom method interatomic potentials for GaN, InN and Ga&lt;sub&gt;1-x&lt;/sub&gt;In&lt;sub&gt;x&lt;/sub&gt;N},\\n url = {https://doi.org/10.1088%2F0953-8984%2F21%2F32%2F325801},\\n volume = {21},\\n year = {2009}\\n}\\n\\n</bibtex></citation></description><implementation><key>ac42b5c8-7db1-41b8-9fca-fdf8e3e97c0b</key><id>2009--Do-E-C--Ga-In--LAMMPS--ipr1</id><status>active</status><date>2019-05-06</date><type>LAMMPS pair_style meam</type><notes><text>These files are based on files obtained from http://cmse.postech.ac.kr/home_2nnmeam.</text></notes><artifact><web-link><URL>https://www.ctcms.nist.gov/potentials/Download/2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-In/1/GaIn.meam</URL><link-text>GaIn.meam</link-text></web-link></artifact><artifact><web-link><URL>https://www.ctcms.nist.gov/potentials/Download/2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-In/1/library.meam</URL><link-text>library.meam</link-t ...

# %%
records.sort_values('last_modification_date')
# Out:
#        id  template  workspace user_id  \
# 9  627770        21          1       2
# 8  627771        21          1       2
# 7  627487        21          1       2
# 6  627577        21          1       2
# 5  627649        21          1       2
# 4  627776        21          1       2
# 3  627678        21          1       2
# 2  627439        21          1       2
# 1  627248        21          1       2
# 0  627879        21          1       2
#
#                                                title  \
# 9  potential.2017--Zhou-X-W-Jones-R-E-Chu-K--In-Ga-N
# 8          potential.2015--Elliott-R-S-Akerson-A--Ga
# 7  potential.2003--Nord-J-Albe-K-Erhart-P-Nordlun...
# 6  potential.2002--Albe-K-Nordlund-K-Nord-J-Kuron...
# 5  potential.2006--Murdick-D-A-Zhou-X-W-Wadley-H-...
# 4               potential.2006--Bere-A-Serra-A--Ga-N
# 3     potential.2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-In
# 2   potential.2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-In-N
# 1      potential.2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-N
# 0               potential.2012--Belashchenko-D-K--Ga
#
#                      creation_date           last_modification_date  \
# 9 2021-08-26 13:14:50.712000-04:00 2022-07-22 18:18:17.939000-04:00
# 8 2021-08-26 13:12:22.444000-04:00 2022-07-22 18:20:05.258000-04:00
# 7 2021-08-26 13:15:18.574000-04:00 2022-07-22 18:23:09.939000-04:00
# 6 2021-08-26 13:15:08.579000-04:00 2022-07-22 18:23:16.059000-04:00
# 5 2021-08-26 13:14:42.650000-04:00 2022-07-22 18:23:41.657000-04:00
# 4 2021-08-26 13:14:01.723000-04:00 2022-07-22 18:24:30.642000-04:00
# 3 2021-08-26 13:11:05.366000-04:00 2022-07-28 15:45:07.448000-04:00
# 2 2021-08-26 13:13:03.653000-04:00 2022-07-28 15:47:10.520000-04:00
# 1 2021-08-26 13:14:20.232000-04:00 2022-07-28 15:48:01.580000-04:00
# 0 2023-10-31 15:55:54.398000-04:00 2023-10-31 15:55:54.398000-04:00
#
#                   last_change_date  \
# 9 2022-07-22 18:18:18.429000-04:00
# 8 2022-07-22 18:20:05.812000-04:00
# 7 2022-07-22 18:23:10.598000-04:00
# 6 2022-07-22 18:23:16.578000-04:00
# 5 2022-07-22 18:23:42.142000-04:00
# 4 2022-07-22 18:24:31.168000-04:00
# 3 2022-07-28 15:45:07.455000-04:00
# 2 2022-07-28 15:47:10.527000-04:00
# 1 2022-07-28 15:48:01.587000-04:00
# 0 2023-10-31 15:55:57.079000-04:00
#
#                                          xml_content template_title
# 9  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 8  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 7  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 6  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 5  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 4  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 3  <interatomic-potential  xmlns:xsi="http://www....      Potential
# 2  <interatomic-potential  xmlns:xsi="http://www....      Potential
# 1  <interatomic-potential  xmlns:xsi="http://www....      Potential
# 0  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
