# %% [markdown]
# # CDCS Public Data Exploration
#
# This provides an example of how anonymous users can query records and templates in a CDCS instance without logging in, assuming read permissions have been set to allow it.

# %%
import cdcs
from cdcs import CDCS

print('Notebook executed for cdcs version', cdcs.__version__)
# Out:
# Notebook executed for cdcs version 0.2.0

# %% [markdown]
# Create client manager with anonymous user

# %%
curator_v2 = CDCS('https://potentials.nist.gov/', username='')
print(curator_v2.cdcsversion)
# Out:
# (2, 15, 0)

# %%
curator_v3 = CDCS('https://test-potentials.nist.gov/', username='', verify=False)
print(curator_v3.cdcsversion)
# Out:
# (3, 0, 1)

# %%
curator = curator_v3

# %% [markdown]
# See the available record templates

# %%
curator.template_titles
# Out:
# ['Action',
#  'calculation_bond_angle_scan',
#  'calculation_diatom_scan',
#  'stacking_fault',
#  'Request',
#  'PotentialProperties',
#  'potential_LAMMPS_KIM',
#  'potential_LAMMPS',
#  'Potential',
#  'free_surface',
#  'FAQ',
#  'crystal_prototype',
#  'Citation',
#  'calculation_isolated_atom',
#  'relaxed_crystal']

# %% [markdown]
# Query and explore the data
#
# __Notes:__ current design downloads all matching records by iterating through all pages until next=None. Need args for
#
# - limit: max # of items
# - page: allows access of those beyond limit
# - nitems: number retrieved per download (available in rest call?)

# %%
curator.query(template='Potential', keyword='Mishin')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 34/34 [00:00<00:00, 58.94it/s]
#       id  template  workspace user_id  \
# 0   3264         9          1       5
# 1   3311         9          1       5
# 2   2806         9          1       5
# 3   3146         9          1       5
# 4   3247         9          1       5
# 5   2981         9          1       5
# 6   2998         9          1       5
# 7   3318         9          1       5
# 8   3345         9          1       5
# 9   2894         9          1       5
# 10  3295         9          1       5
# 11  3013         9          1       5
# 12  3084         9          1       5
# 13  2997         9          1       5
# 14  3184         9          1       5
# 15  3082         9          1       5
# 16  3132         9          1       5
# 17  3258         9          1       5
# 18  2846         9          1       5
# 19  3288         9          1       5
# 20  2986         9          1       5
# 21  3291         9          1       5
# 22  2768         9          1       5
# 23  3057         9          1       5
# 24  2932         9          1       5
# 25  3225         9          1       5
# 26  3034         9          1       5
# 27  2868         9          1       5
# 28  2917         9          1       5
# 29  2717         9          1       5
# 30  2794         9          1       5
# 31  3246         9          1       5
# 32  3038         9          1       5
# 33  3078         9          1       5
#
#                                                 title  \
# 0          potential.2017--Purja-Pun-G-P-Mishin-Y--Si
# 1   potential.2016--Samolyuk-G-D-Beland-L-K-Stocks...
# 2          potential.2012--Purja-Pun-G-P-Mishin-Y--Co
# 3            potential.2010--Apostol-F-Mishin-Y--Al-H
# 4                     potential.2004--Mishin-Y--Ni-Al
# 5   potential.2002--Mishin-Y-Mehl-M-J-Papaconstant...
# 6   potential.2001--Mishin-Y-Mehl-M-J-Papaconstant...
# 7   potential.2001--Mishin-Y-Mehl-M-J-Papaconstant...
# 8         potential.2018--Howells-C-A-Mishin-Y--Cr-Ni
# 9               potential.2003--Zope-R-R-Mishin-Y--Al
# 10  potential.2005--Mishin-Y-Mehl-M-J-Papaconstant...
# 11  potential.1999--Mishin-Y-Farkas-D-Mehl-M-J-Pap...
# 23 2021-08-26 13:12:33.264000+00:00      Potential
# 24 2021-08-26 13:12:28.629000+00:00      Potential
# 25 2021-08-26 13:12:22.278000+00:00      Potential
# 26 2021-08-26 13:12:14.202000+00:00      Potential
# 27 2021-08-26 13:11:54.927000+00:00      Potential
# 28 2021-08-26 13:11:51.946000+00:00      Potential
# 29 2021-08-26 13:11:25.839000+00:00      Potential
# 30 2021-08-26 13:11:02.239000+00:00      Potential
# 31 2021-08-26 13:10:52.477000+00:00      Potential
# 32 2021-08-26 13:10:51.468000+00:00      Potential
# 33 2021-08-26 13:10:25.226000+00:00      Potential

# %% [markdown]
# Same function for both keyword and query calls (which rest url is used is handled underneath).

# %%
records = curator.query(mongoquery={'interatomic-potential.element':'Ga'})
records
# Out:
#      id  template  workspace user_id  \
# 0  3335         9          1       5
# 1  3325         9          1       5
# 2  2733         9          1       5
# 3  3333         9          1       5
# 4  3021         9          1       5
# 5  2742         9          1       5
# 6  2801         9          1       5
# 7  2941         9          1       5
# 8  3144         9          1       5
#
#                                                title  \
# 0      potential.2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-N
# 1   potential.2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-In-N
# 2     potential.2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-In
# 3  potential.2017--Zhou-X-W-Jones-R-E-Chu-K--In-Ga-N
# 4          potential.2015--Elliott-R-S-Akerson-A--Ga
# 5  potential.2003--Nord-J-Albe-K-Erhart-P-Nordlun...
# 6  potential.2002--Albe-K-Nordlund-K-Nord-J-Kuron...
# 7  potential.2006--Murdick-D-A-Zhou-X-W-Wadley-H-...
# 8               potential.2006--Bere-A-Serra-A--Ga-N
#
#                                          xml_content  \
# 0  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 1  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 2  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 3  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 4  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 5  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 6  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 7  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 8  <?xml version="1.0" encoding="utf-8"?>\n<inter...
#
#                      creation_date           last_modification_date  \
# 0 2021-08-26 13:14:20.232000+00:00 2022-01-14 20:53:59.021000+00:00
# 1 2021-08-26 13:13:03.653000+00:00 2022-01-14 20:53:53.393000+00:00
# 2 2021-08-26 13:11:05.366000+00:00 2022-01-14 20:53:44.135000+00:00
# 3 2021-08-26 13:14:50.712000+00:00 2021-11-30 16:53:29.465000+00:00
# 4 2021-08-26 13:12:22.444000+00:00 2021-11-30 16:50:20.873000+00:00
# 5 2021-08-26 13:15:18.574000+00:00 2021-08-26 13:15:18.574000+00:00
# 6 2021-08-26 13:15:08.579000+00:00 2021-08-26 13:15:08.579000+00:00
# 7 2021-08-26 13:14:42.650000+00:00 2021-08-26 13:14:42.650000+00:00
# 8 2021-08-26 13:14:01.723000+00:00 2021-08-26 13:14:01.723000+00:00
#
#                   last_change_date template_title
# 0 2022-01-14 20:53:59.029000+00:00      Potential
# 1 2022-01-14 20:53:53.400000+00:00      Potential
# 2 2022-01-14 20:53:44.276000+00:00      Potential
# 3 2021-11-30 16:53:29.471000+00:00      Potential
# 4 2021-11-30 16:50:20.879000+00:00      Potential
# 5 2021-08-26 13:15:18.896000+00:00      Potential
# 6 2021-08-26 13:15:08.904000+00:00      Potential
# 7 2021-08-26 13:14:42.982000+00:00      Potential
# 8 2021-08-26 13:14:02.041000+00:00      Potential

# %% [markdown]
# Note that the fetched content is returned as a pandas.DataFrame. This allows for the content to be easily explored and further parsed.

# %%
records.title
# Out:
# 0        potential.2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-N
# 1     potential.2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-In-N
# 2       potential.2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-In
# 3    potential.2017--Zhou-X-W-Jones-R-E-Chu-K--In-Ga-N
# 4            potential.2015--Elliott-R-S-Akerson-A--Ga
# 5    potential.2003--Nord-J-Albe-K-Erhart-P-Nordlun...
# 6    potential.2002--Albe-K-Nordlund-K-Nord-J-Kuron...
# 7    potential.2006--Murdick-D-A-Zhou-X-W-Wadley-H-...
# 8                 potential.2006--Bere-A-Serra-A--Ga-N
# Name: title, dtype: object

# %%
records.xml_content[3]
# Out:
# '<?xml version="1.0" encoding="utf-8"?>\n<interatomic-potential><key>f4c3e281-bafc-4d23-9571-a796d8b1053f</key><id>2017--Zhou-X-W-Jones-R-E-Chu-K--In-Ga-N</id><record-version>2019-09-05</record-version><description><citation><document-type>journal</document-type><title>Polymorphic improvement of Stillinger-Weber potential for InGaN</title><author><given-name>X.W.</given-name><surname>Zhou</surname></author><author><given-name>R.E.</given-name><surname>Jones</surname></author><author><given-name>K.</given-name><surname>Chu</surname></author><publication-name>Journal of Applied Physics</publication-name><publication-date><year>2017</year></publication-date><volume>122</volume><issue>23</issue><abstract>A Stillinger-Weber potential is computationally very efficient for molecular dynamics simulations.  Despite its simple mathematical form, the Stillinger-Weber potential can be easily parameterized to ensure that crystal structures with tetrahedral bond angles (e.g., diamond-cubic, zinc-blende, and wurtzite) are stable and have the lowest energy. As a result, the Stillinger-Weber potential has been widely used to study a variety of semiconductor elements and alloys. When studying an A-B binary system, however, the Stillinger-Weber potential is associated with two major drawbacks. First, it significantly overestimates the elastic constants of elements A and B, limiting its use for systems involving both compounds and elements (e.g., an A/AB multilayer). Second, it prescribes equal energy for zinc-blende and wurtzite crystals, limiting its use for compounds with large stacking fault energies. Here, we utilize the polymorphic potential style recently implemented in LAMMPS to develop a modified Stillinger-Weber potential for InGaN that overcomes these two problems.</abstract><pages>235703</pages><DOI>10.1063/1.5001339</DOI><bibtex>@article{Zhou_2017,\\n abstract = {A Stillinger-Weber potential is computationally very efficient for molecular dynamics simulations.  Despite its simple mathematical form, the Stillinger-Weber potential can be easily parameterized to ensure that crystal structures with tetrahedral bond angles (e.g., diamond-cubic, zinc-blende, and wurtzite) are stable and have the lowest energy. As a result, the Stillinger-Weber potential has been widely used to study a variety of semiconductor elements and alloys. When studying an A-B binary system, however, the Stillinger-Weber potential is associated with two major drawbacks. First, it significantly overestimates the elastic constants of elements A and B, limiting its use for systems involving both compounds and elements (e.g., an A/AB multilayer). Second, it prescribes equal energy for zinc-blende and wurtzite crystals, limiting its use for compounds with large stacking fault energies. Here, we utilize the polymorphic potential style recently implemented in LAMMPS to develop a modified Stillinger-Weber potential for InGaN that overcomes these two problems.},\\n author = {X. W. Zhou and R. E. Jones and K. Chu},\\n doi = {10.1063/1.5001339},\\n journal = {Journal of Applied Physics},\\n month = {dec},\\n number = {23},\\n pages = {235703},\\n publisher = {AIP Publishing},\\n title = {Polymorphic improvement of Stillinger-Weber potential for InGaN},\\n url = {https://doi.org/10.1063%2F1.5001339},\\n volume = {122},\\n year = {2017}\\n}\\n\\n</bibtex></citation></description><implementation><key>f4fb9bd7-3199-4861-9a05-6f2e9013b63e</key><id>2017--Zhou-X-W--In-Ga-N--LAMMPS--ipr1</id><status>active</status><date>2019-09-05</date><type>LAMMPS pair_style polymorphic</type><notes><text>This file was provided by Xiaowang Zhou (Sandia) on 16 August 2019.</text></notes><artifact><web-link><URL>https://www.ctcms.nist.gov/potentials/Download/2017--Zhou-X-W-Jones-R-E-Chu-K--In-Ga-N/1/InGaN.psw</URL><link-text>InGaN.psw</link-text></web-link></artifact></implementation><element>In</element><element>Ga</element><element>N</element></interatomic-potential>'

# %%
records.sort_values('last_modification_date')
# Out:
#      id  template  workspace user_id  \
# 8  3144         9          1       5
# 7  2941         9          1       5
# 6  2801         9          1       5
# 5  2742         9          1       5
# 4  3021         9          1       5
# 3  3333         9          1       5
# 2  2733         9          1       5
# 1  3325         9          1       5
# 0  3335         9          1       5
#
#                                                title  \
# 8               potential.2006--Bere-A-Serra-A--Ga-N
# 7  potential.2006--Murdick-D-A-Zhou-X-W-Wadley-H-...
# 6  potential.2002--Albe-K-Nordlund-K-Nord-J-Kuron...
# 5  potential.2003--Nord-J-Albe-K-Erhart-P-Nordlun...
# 4          potential.2015--Elliott-R-S-Akerson-A--Ga
# 3  potential.2017--Zhou-X-W-Jones-R-E-Chu-K--In-Ga-N
# 2     potential.2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-In
# 1   potential.2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-In-N
# 0      potential.2009--Do-E-C-Shin-Y-H-Lee-B-J--Ga-N
#
#                                          xml_content  \
# 8  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 7  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 6  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 5  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 4  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 3  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 2  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 1  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 0  <?xml version="1.0" encoding="utf-8"?>\n<inter...
#
#                      creation_date           last_modification_date  \
# 8 2021-08-26 13:14:01.723000+00:00 2021-08-26 13:14:01.723000+00:00
# 7 2021-08-26 13:14:42.650000+00:00 2021-08-26 13:14:42.650000+00:00
# 6 2021-08-26 13:15:08.579000+00:00 2021-08-26 13:15:08.579000+00:00
# 5 2021-08-26 13:15:18.574000+00:00 2021-08-26 13:15:18.574000+00:00
# 4 2021-08-26 13:12:22.444000+00:00 2021-11-30 16:50:20.873000+00:00
# 3 2021-08-26 13:14:50.712000+00:00 2021-11-30 16:53:29.465000+00:00
# 2 2021-08-26 13:11:05.366000+00:00 2022-01-14 20:53:44.135000+00:00
# 1 2021-08-26 13:13:03.653000+00:00 2022-01-14 20:53:53.393000+00:00
# 0 2021-08-26 13:14:20.232000+00:00 2022-01-14 20:53:59.021000+00:00
#
#                   last_change_date template_title
# 8 2021-08-26 13:14:02.041000+00:00      Potential
# 7 2021-08-26 13:14:42.982000+00:00      Potential
# 6 2021-08-26 13:15:08.904000+00:00      Potential
# 5 2021-08-26 13:15:18.896000+00:00      Potential
# 4 2021-11-30 16:50:20.879000+00:00      Potential
# 3 2021-11-30 16:53:29.471000+00:00      Potential
# 2 2022-01-14 20:53:44.276000+00:00      Potential
# 1 2022-01-14 20:53:53.400000+00:00      Potential
# 0 2022-01-14 20:53:59.029000+00:00      Potential
