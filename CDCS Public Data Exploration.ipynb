# %% [markdown]
# # CDCS Public Data Exploration

# %%
from cdcs import CDCS

# %% [markdown]
# Create client manager with anonymous user

# %%
curator = CDCS('https://potentials.nist.gov/', username='')

# %% [markdown]
# See the available record templates

# %%
curator.template_titles
# Out:
# ['Potential',
#  'Family',
#  'FAQ',
#  'Action',
#  'PotentialProperties',
#  'Request',
#  'free_surface',
#  'stacking_fault',
#  'dislocation',
#  'point_defect',
#  'crystal_prototype',
#  'potential_LAMMPS',
#  'Citation']

# %% [markdown]
# Query and explore the data
#
# __Notes:__ current design downloads all matching records by iterating through all pages until next=None. Need args for
#
# - limit: max # of items
# - page: allows access of those beyond limit
# - nitems: number retrieved per download (available in rest call?)

# %%
curator.query(template='Potential', keyword='Mishin')
# Out:
#                           id                  template  \
# 0   5df2acea90985100349d7bc3  5df2ac9890985100349d7ad7
# 1   5df2ad06909851002d9d7b02  5df2ac9890985100349d7ad7
# 2   5df2acba909851002d9d7ade  5df2ac9890985100349d7ad7
# 3   5df2acbf90985100349d7b57  5df2ac9890985100349d7ad7
# 4   5df2acbd90985100329d7af9  5df2ac9890985100349d7ad7
# 5   5df2acac90985100319d7ae1  5df2ac9890985100349d7ad7
# 6   5df2ad0490985100349d7c1b  5df2ac9890985100349d7ad7
# 7   5df2acab90985100319d7add  5df2ac9890985100349d7ad7
# 8   5df2acb790985100349d7b43  5df2ac9890985100349d7ad7
# 9   5df2acd390985100349d7b97  5df2ac9890985100349d7ad7
# 10  5df2acd290985100339d7b12  5df2ac9890985100349d7ad7
# 11  5df2acd3909851002f9d7ae9  5df2ac9890985100349d7ad7
# 12  5df2ad0490985100329d7b31  5df2ac9890985100349d7ad7
# 13  5df2aca690985100349d7aff  5df2ac9890985100349d7ad7
# 14  5df2ad0790985100269d7bbf  5df2ac9890985100349d7ad7
# 15  5df2acab90985100339d7aed  5df2ac9890985100349d7ad7
# 16  5df2acb690985100349d7b3f  5df2ac9890985100349d7ad7
# 17  5df2acb590985100349d7b37  5df2ac9890985100349d7ad7
# 18  5df2aca790985100339d7ae5  5df2ac9890985100349d7ad7
# 19  5df2acf990985100349d7beb  5df2ac9890985100349d7ad7
# 20  5df2acc490985100319d7afd  5df2ac9890985100349d7ad7
# 21  5df2acf590985100349d7bdb  5df2ac9890985100349d7ad7
# 22  5df2acf690985100349d7bdf  5df2ac9890985100349d7ad7
# 23  5df2acf690985100269d7b8b  5df2ac9890985100349d7ad7
# 24  5df2acf590985100319d7b15  5df2ac9890985100349d7ad7
# 25  5df2acbe90985100339d7afa  5df2ac9890985100349d7ad7
# 26  5df2acbe90985100269d7b11  5df2ac9890985100349d7ad7
# 27  5df2ad0990985100269d7bcb  5df2ac9890985100349d7ad7
# 28  5df2ad0f909851002c9d7b12  5df2ac9890985100349d7ad7
# 29  5df2aca390985100339d7ae1  5df2ac9890985100349d7ad7
# 30  5df2ad0e90985100349d7c37  5df2ac9890985100349d7ad7
# 31  5df2ad0e90985100349d7c2f  5df2ac9890985100349d7ad7
# 32  5df2acbc90985100349d7b4f  5df2ac9890985100349d7ad7
#
#                    workspace user_id  \
# 0   5de9613a75d7d40014ffb6fc       2
# 1   5de9613a75d7d40014ffb6fc       2
# 2   5de9613a75d7d40014ffb6fc       2
# 3   5de9613a75d7d40014ffb6fc       2
# 4   5de9613a75d7d40014ffb6fc       2
# 5   5de9613a75d7d40014ffb6fc       2
# 6   5de9613a75d7d40014ffb6fc       2
# 7   5de9613a75d7d40014ffb6fc       2
# 8   5de9613a75d7d40014ffb6fc       2
# 9   5de9613a75d7d40014ffb6fc       2
# 10  5de9613a75d7d40014ffb6fc       2
# 11  5de9613a75d7d40014ffb6fc       2
# 12  5de9613a75d7d40014ffb6fc       2
# 13  5de9613a75d7d40014ffb6fc       2
# 14  5de9613a75d7d40014ffb6fc       2
# 15  5de9613a75d7d40014ffb6fc       2
# 16  5de9613a75d7d40014ffb6fc       2
# 17  5de9613a75d7d40014ffb6fc       2
# 18  5de9613a75d7d40014ffb6fc       2
# 19  5de9613a75d7d40014ffb6fc       2
# 20  5de9613a75d7d40014ffb6fc       2
# 21  5de9613a75d7d40014ffb6fc       2
# 22  5de9613a75d7d40014ffb6fc       2
# 23  5de9613a75d7d40014ffb6fc       2
# 24  5de9613a75d7d40014ffb6fc       2
# 25  5de9613a75d7d40014ffb6fc       2
# 26  5de9613a75d7d40014ffb6fc       2
# 27  5de9613a75d7d40014ffb6fc       2
# 28  5de9613a75d7d40014ffb6fc       2
# 29  5de9613a75d7d40014ffb6fc       2
# 30  5de9613a75d7d40014ffb6fc       2
# 31  5de9613a75d7d40014ffb6fc       2
# 32  5de9613a75d7d40014ffb6fc       2
#
#                                                 title  \
# 0           potential.2011--Apostol-F-Mishin-Y--Al-Cu
# 1   potential.2005--Mishin-Y-Mehl-M-J-Papaconstant...
# 2   potential.2008--Hashibon-A-Lozovoi-A-Y-Mishin-...
# 3            potential.2010--Apostol-F-Mishin-Y--Al-H
# 4       potential.2009--Purja-Pun-G-P-Mishin-Y--Ni-Al
# 5                     potential.2004--Mishin-Y--Ni-Al
# 6   potential.2002--Mishin-Y-Mehl-M-J-Papaconstant...
# 7            potential.2003--Zope-R-R-Mishin-Y--Ti-Al
# 8   potential.2006--Williams-P-L-Mishin-Y-Hamilton...
# 9   potential.2015--Purja-Pun-G-P-Yamakov-V-Mishin...
# 10  potential.2015--Purja-Pun-G-P-Yamakov-V-Mishin...
# 11  potential.2015--Purja-Pun-G-P-Yamakov-V-Mishin...
# 12  potential.1999--Mishin-Y-Farkas-D-Mehl-M-J-Pap...
# 13  potential.1999--Mishin-Y-Farkas-D-Mehl-M-J-Pap...
# 14  potential.2001--Mishin-Y-Mehl-M-J-Papaconstant...
# 15              potential.2003--Zope-R-R-Mishin-Y--Al
# 16  potential.2006--Williams-P-L-Mishin-Y-Hamilton...
# 17  potential.2006--Chamati-H-Papanicolaou-N-I-Mis...
# 18  potential.2001--Mishin-Y-Mehl-M-J-Papaconstant...
# 19  potential.2015--Purja-Pun-G-P-Darling-K-A-Kecs...
# 20         potential.2012--Purja-Pun-G-P-Mishin-Y--Co
# 21           potential.2018--Howells-C-A-Mishin-Y--Cr
# 22        potential.2018--Howells-C-A-Mishin-Y--Cr-Ni
# 23         potential.2017--Purja-Pun-G-P-Mishin-Y--Si
# 24  potential.2015--Purja-Pun-G-P-Darling-K-A-Kecs...
# 25  potential.2009--Zhakhovskii-V-V-Inogamov-N-A-P...
# 26  potential.2009--Zhakhovskii-V-V-Inogamov-N-A-P...
# 27          potential.2009--Wu-H-H-Trinkle-D-R--Cu-Ag
# 28  potential.2016--Beland-L-K-Lu-C-Osetskiy-Y-N-e...
# 29         potential.1996--Farkas-D-Jones-C--Nb-Ti-Al
# 30  potential.2016--Stoller-R-E-Tamm-A-Beland-L-K-...
# 31  potential.2016--Samolyuk-G-D-Beland-L-K-Stocks...
# 32  potential.2009--Bonny-G-Pasianot-R-C-Castin-N-...
#
#                                           xml_content  \
# 0   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 1   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 2   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 3   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 4   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 5   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 6   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 7   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 8   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 9   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 10  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 11  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 12  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 13  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 14  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 15  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 16  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 17  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 18  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 19  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 20  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 21  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 22  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 23  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 24  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 25  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 26  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 27  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 28  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 29  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 30  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 31  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 32  <?xml version="1.0" encoding="utf-8"?>\n<inter...
#
#          last_modification_date template_title
# 0   2020-01-02T19:48:21.392000Z      Potential
# 1   2019-12-17T18:37:08.860000Z      Potential
# 2   2020-01-02T17:38:08.283000Z      Potential
# 3   2019-12-17T18:36:22.347000Z      Potential
# 4   2019-12-17T18:36:21.280000Z      Potential
# 5   2019-12-17T18:36:11.239000Z      Potential
# 6   2019-12-17T18:37:07.644000Z      Potential
# 7   2020-01-02T17:06:34.527000Z      Potential
# 8   2019-12-17T18:36:17.771000Z      Potential
# 9   2020-01-02T19:25:05.256000Z      Potential
# 10  2020-01-02T19:22:59.985000Z      Potential
# 11  2020-01-02T19:24:02.799000Z      Potential
# 12  2019-12-17T18:37:07.406000Z      Potential
# 13  2019-12-17T18:36:07.714000Z      Potential
# 14  2019-12-17T18:37:11.324000Z      Potential
# 15  2020-01-02T17:04:25.916000Z      Potential
# 16  2019-12-17T18:36:17.489000Z      Potential
# 17  2019-12-17T18:36:17.019000Z      Potential
# 18  2019-12-17T18:36:08.405000Z      Potential
# 19  2019-12-17T18:37:00.278000Z      Potential
# 20  2019-12-17T18:36:25.873000Z      Potential
# 21  2019-12-17T18:36:58.066000Z      Potential
# 22  2019-12-17T18:36:58.379000Z      Potential
# 23  2019-12-17T18:36:58.537000Z      Potential
# 24  2019-12-17T18:36:57.608000Z      Potential
# 25  2019-12-17T18:36:22.062000Z      Potential
# 26  2019-12-17T18:36:21.798000Z      Potential
# 27  2019-12-17T18:37:12.382000Z      Potential
# 28  2020-01-02T20:36:11.088000Z      Potential
# 29  2019-12-17T18:36:06.145000Z      Potential
# 30  2019-12-17T18:37:15.262000Z      Potential
# 31  2019-12-17T18:37:14.812000Z      Potential
# 32  2019-12-17T18:36:20.441000Z      Potential

# %% [markdown]
# Same function for both keyword and query calls (which rest url is used is handled underneath).

# %%
curator.query(mongoquery={'interatomic-potential.element':'Ga'})
# Out:
#                          id                  template  \
# 0  5df2ace890985100269d7b73  5df2ac9890985100349d7ad7
# 1  5df2ace990985100309d7af9  5df2ac9890985100349d7ad7
# 2  5df2aced909851002d9d7afa  5df2ac9890985100349d7ad7
# 3  5df2acf190985100349d7bd3  5df2ac9890985100349d7ad7
# 4  5df2ad0c90985100339d7b46  5df2ac9890985100349d7ad7
#
#                   workspace user_id  \
# 0  5de9613a75d7d40014ffb6fc       2
# 1  5de9613a75d7d40014ffb6fc       2
# 2  5de9613a75d7d40014ffb6fc       2
# 3  5de9613a75d7d40014ffb6fc       2
# 4  5de9613a75d7d40014ffb6fc       2
#
#                                                title  \
# 0  potential.2002--Albe-K-Nordlund-K-Nord-J-Kuron...
# 1  potential.2003--Nord-J-Albe-K-Erhart-P-Nordlun...
# 2  potential.2006--Murdick-D-A-Zhou-X-W-Wadley-H-...
# 3               potential.2006--Bere-A-Serra-A--Ga-N
# 4  potential.2017--Zhou-X-W-Jones-R-E-Chu-K--In-Ga-N
#
#                                          xml_content  \
# 0  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 1  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 2  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 3  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 4  <?xml version="1.0" encoding="utf-8"?>\n<inter...
#
#         last_modification_date template_title
# 0  2019-12-17T18:36:49.686000Z      Potential
# 1  2019-12-17T18:36:49.950000Z      Potential
# 2  2019-12-17T18:36:52.242000Z      Potential
# 3  2019-12-17T18:36:54.561000Z      Potential
# 4  2019-12-17T18:37:13.748000Z      Potential
