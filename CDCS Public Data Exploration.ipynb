# %% [markdown]
# # CDCS Public Data Exploration

# %%
from cdcs import CDCS

# %% [markdown]
# Create client manager with anonymous user

# %%
curator = CDCS('https://potentials.nist.gov/', username='')

# %% [markdown]
# See the available record templates

# %%
curator.template_titles
# Out:
# ['Potential',
#  'Family',
#  'FAQ',
#  'Action',
#  'PotentialProperties',
#  'Request',
#  'free_surface',
#  'stacking_fault',
#  'dislocation',
#  'point_defect',
#  'crystal_prototype',
#  'potential_LAMMPS',
#  'Citation',
#  'relaxed_crystal',
#  'calculation_diatom_scan',
#  'calculation_isolated_atom']

# %% [markdown]
# Query and explore the data
#
# __Notes:__ current design downloads all matching records by iterating through all pages until next=None. Need args for
#
# - limit: max # of items
# - page: allows access of those beyond limit
# - nitems: number retrieved per download (available in rest call?)

# %%
curator.query(template='Potential', keyword='Mishin')
# Out:
#                           id       last_modification_date  \
# 0   5df2ad06909851002d9d7b02  2020-03-05T14:27:15.432000Z
# 1   5df2acea90985100349d7bc3  2020-03-04T19:07:30.091000Z
# 2   5df2acba909851002d9d7ade  2020-03-05T14:42:01.230000Z
# 3   5df2acbf90985100349d7b57  2020-03-04T20:00:03.332000Z
# 4   5df2acbd90985100329d7af9  2020-03-04T19:36:07.910000Z
# 5   5df2acac90985100319d7ae1  2020-09-02T17:23:32.838000Z
# 6   5df2ad0490985100349d7c1b  2020-03-04T19:04:22.553000Z
# 7   5df2acab90985100319d7add  2020-03-04T20:22:02.858000Z
# 8   5df2acb790985100349d7b43  2020-03-04T20:48:40.648000Z
# 9   5df2ad0490985100329d7b31  2020-03-05T16:25:25.802000Z
# 10  5df2aca690985100349d7aff  2020-03-04T18:22:48.123000Z
# 11  5df2ad0790985100269d7bbf  2020-03-05T14:23:58.936000Z
# 12  5df2acd390985100349d7b97  2020-01-02T19:25:05.256000Z
# 13  5df2acd290985100339d7b12  2020-01-02T19:22:59.985000Z
# 14  5df2acd3909851002f9d7ae9  2020-01-02T19:24:02.799000Z
# 15  5df2acab90985100339d7aed  2020-03-04T19:28:11.679000Z
# 16  5df2acb690985100349d7b3f  2020-03-04T22:38:37.310000Z
# 17  5df2acb590985100349d7b37  2020-03-04T21:58:29.789000Z
# 18  5df2aca790985100339d7ae5  2020-03-05T16:54:29.151000Z
# 19  5df2acf990985100349d7beb  2019-12-17T18:37:00.278000Z
# 20  5df2acc490985100319d7afd  2019-12-17T18:36:25.873000Z
# 21  5df2acf590985100349d7bdb  2019-12-17T18:36:58.066000Z
# 22  5df2acf690985100349d7bdf  2019-12-17T18:36:58.379000Z
# 23  5df2acf690985100269d7b8b  2019-12-17T18:36:58.537000Z
# 24  5df2acf590985100319d7b15  2019-12-17T18:36:57.608000Z
# 25  5df2acbe90985100339d7afa  2020-03-31T17:35:15.770000Z
# 26  5df2acbe90985100269d7b11  2020-03-31T17:36:26.933000Z
# 27  5e5eaf57ab2f7c002d01110d  2020-08-14T15:15:29.559000Z
# 28  5df2ad0990985100269d7bcb  2019-12-17T18:37:12.382000Z
# 29  5df2ad0f909851002c9d7b12  2020-01-02T20:36:11.088000Z
# 30  5df2aca390985100339d7ae1  2020-03-05T16:29:33.209000Z
# 31  5df2ad0e90985100349d7c37  2019-12-17T18:37:15.262000Z
# 32  5df2ad0e90985100349d7c2f  2019-12-17T18:37:14.812000Z
# 33  5df2acbc90985100349d7b4f  2020-03-05T14:32:55.373000Z
#
#                     template  \
# 0   5df2ac9890985100349d7ad7
# 1   5df2ac9890985100349d7ad7
# 2   5df2ac9890985100349d7ad7
# 3   5df2ac9890985100349d7ad7
# 4   5df2ac9890985100349d7ad7
# 5   5df2ac9890985100349d7ad7
# 6   5df2ac9890985100349d7ad7
# 7   5df2ac9890985100349d7ad7
# 8   5df2ac9890985100349d7ad7
# 9   5df2ac9890985100349d7ad7
# 10  5df2ac9890985100349d7ad7
# 11  5df2ac9890985100349d7ad7
# 12  5df2ac9890985100349d7ad7
# 13  5df2ac9890985100349d7ad7
# 14  5df2ac9890985100349d7ad7
# 15  5df2ac9890985100349d7ad7
# 16  5df2ac9890985100349d7ad7
# 17  5df2ac9890985100349d7ad7
# 18  5df2ac9890985100349d7ad7
# 19  5df2ac9890985100349d7ad7
# 20  5df2ac9890985100349d7ad7
# 21  5df2ac9890985100349d7ad7
# 22  5df2ac9890985100349d7ad7
# 23  5df2ac9890985100349d7ad7
# 24  5df2ac9890985100349d7ad7
# 25  5df2ac9890985100349d7ad7
# 26  5df2ac9890985100349d7ad7
# 27  5df2ac9890985100349d7ad7
# 28  5df2ac9890985100349d7ad7
# 29  5df2ac9890985100349d7ad7
# 30  5df2ac9890985100349d7ad7
# 31  5df2ac9890985100349d7ad7
# 32  5df2ac9890985100349d7ad7
# 33  5df2ac9890985100349d7ad7
#
#                                                 title user_id  \
# 0   potential.2005--Mishin-Y-Mehl-M-J-Papaconstant...       2
# 1           potential.2011--Apostol-F-Mishin-Y--Al-Cu       2
# 2   potential.2008--Hashibon-A-Lozovoi-A-Y-Mishin-...       2
# 3            potential.2010--Apostol-F-Mishin-Y--Al-H       2
# 4       potential.2009--Purja-Pun-G-P-Mishin-Y--Ni-Al       2
# 5                     potential.2004--Mishin-Y--Ni-Al       2
# 6   potential.2002--Mishin-Y-Mehl-M-J-Papaconstant...       2
# 7            potential.2003--Zope-R-R-Mishin-Y--Ti-Al       2
# 8   potential.2006--Williams-P-L-Mishin-Y-Hamilton...       2
# 9   potential.1999--Mishin-Y-Farkas-D-Mehl-M-J-Pap...       2
# 10  potential.1999--Mishin-Y-Farkas-D-Mehl-M-J-Pap...       2
# 11  potential.2001--Mishin-Y-Mehl-M-J-Papaconstant...       2
# 12  potential.2015--Purja-Pun-G-P-Yamakov-V-Mishin...       2
# 13  potential.2015--Purja-Pun-G-P-Yamakov-V-Mishin...       2
# 14  potential.2015--Purja-Pun-G-P-Yamakov-V-Mishin...       2
# 15              potential.2003--Zope-R-R-Mishin-Y--Al       2
# 16  potential.2006--Williams-P-L-Mishin-Y-Hamilton...       2
# 17  potential.2006--Chamati-H-Papanicolaou-N-I-Mis...       2
# 18  potential.2001--Mishin-Y-Mehl-M-J-Papaconstant...       2
# 19  potential.2015--Purja-Pun-G-P-Darling-K-A-Kecs...       2
# 20         potential.2012--Purja-Pun-G-P-Mishin-Y--Co       2
# 21           potential.2018--Howells-C-A-Mishin-Y--Cr       2
# 22        potential.2018--Howells-C-A-Mishin-Y--Cr-Ni       2
# 23         potential.2017--Purja-Pun-G-P-Mishin-Y--Si       2
# 24  potential.2015--Purja-Pun-G-P-Darling-K-A-Kecs...       2
# 25  potential.2009--Zhakhovskii-V-V-Inogamov-N-A-P...       2
# 26  potential.2009--Zhakhovskii-V-V-Inogamov-N-A-P...       2
# 27  potential.2019--Fischer-F-Schmitz-G-Eich-S-M--...       2
# 28          potential.2009--Wu-H-H-Trinkle-D-R--Cu-Ag       2
# 29  potential.2016--Beland-L-K-Lu-C-Osetskiy-Y-N-e...       2
# 30         potential.1996--Farkas-D-Jones-C--Nb-Ti-Al       2
# 31  potential.2016--Stoller-R-E-Tamm-A-Beland-L-K-...       2
# 32  potential.2016--Samolyuk-G-D-Beland-L-K-Stocks...       2
# 33  potential.2009--Bonny-G-Pasianot-R-C-Castin-N-...       2
#
#                    workspace  \
# 0   5de9613a75d7d40014ffb6fc
# 1   5de9613a75d7d40014ffb6fc
# 2   5de9613a75d7d40014ffb6fc
# 3   5de9613a75d7d40014ffb6fc
# 4   5de9613a75d7d40014ffb6fc
# 5   5de9613a75d7d40014ffb6fc
# 6   5de9613a75d7d40014ffb6fc
# 7   5de9613a75d7d40014ffb6fc
# 8   5de9613a75d7d40014ffb6fc
# 9   5de9613a75d7d40014ffb6fc
# 10  5de9613a75d7d40014ffb6fc
# 11  5de9613a75d7d40014ffb6fc
# 12  5de9613a75d7d40014ffb6fc
# 13  5de9613a75d7d40014ffb6fc
# 14  5de9613a75d7d40014ffb6fc
# 15  5de9613a75d7d40014ffb6fc
# 16  5de9613a75d7d40014ffb6fc
# 17  5de9613a75d7d40014ffb6fc
# 18  5de9613a75d7d40014ffb6fc
# 19  5de9613a75d7d40014ffb6fc
# 20  5de9613a75d7d40014ffb6fc
# 21  5de9613a75d7d40014ffb6fc
# 22  5de9613a75d7d40014ffb6fc
# 23  5de9613a75d7d40014ffb6fc
# 24  5de9613a75d7d40014ffb6fc
# 25  5de9613a75d7d40014ffb6fc
# 26  5de9613a75d7d40014ffb6fc
# 27  5de9613a75d7d40014ffb6fc
# 28  5de9613a75d7d40014ffb6fc
# 29  5de9613a75d7d40014ffb6fc
# 30  5de9613a75d7d40014ffb6fc
# 31  5de9613a75d7d40014ffb6fc
# 32  5de9613a75d7d40014ffb6fc
# 33  5de9613a75d7d40014ffb6fc
#
#                                           xml_content template_title
# 0   <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 1   <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 2   <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 3   <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 4   <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 5   <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 6   <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 7   <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 8   <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 9   <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 10  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 11  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 12  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 13  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 14  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 15  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 16  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 17  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 18  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 19  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 20  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 21  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 22  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 23  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 24  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 25  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 26  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 27  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 28  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 29  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 30  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 31  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 32  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 33  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential

# %% [markdown]
# Same function for both keyword and query calls (which rest url is used is handled underneath).

# %%
curator.query(mongoquery={'interatomic-potential.element':'Ga'})
# Out:
#                          id       last_modification_date  \
# 0  5df2ace890985100269d7b73  2019-12-17T18:36:49.686000Z
# 1  5df2ace990985100309d7af9  2019-12-17T18:36:49.950000Z
# 2  5df2aced909851002d9d7afa  2019-12-17T18:36:52.242000Z
# 3  5df2acf190985100349d7bd3  2019-12-17T18:36:54.561000Z
# 4  5df2ad0c90985100339d7b46  2019-12-17T18:37:13.748000Z
#
#                    template  \
# 0  5df2ac9890985100349d7ad7
# 1  5df2ac9890985100349d7ad7
# 2  5df2ac9890985100349d7ad7
# 3  5df2ac9890985100349d7ad7
# 4  5df2ac9890985100349d7ad7
#
#                                                title user_id  \
# 0  potential.2002--Albe-K-Nordlund-K-Nord-J-Kuron...       2
# 1  potential.2003--Nord-J-Albe-K-Erhart-P-Nordlun...       2
# 2  potential.2006--Murdick-D-A-Zhou-X-W-Wadley-H-...       2
# 3               potential.2006--Bere-A-Serra-A--Ga-N       2
# 4  potential.2017--Zhou-X-W-Jones-R-E-Chu-K--In-Ga-N       2
#
#                   workspace  \
# 0  5de9613a75d7d40014ffb6fc
# 1  5de9613a75d7d40014ffb6fc
# 2  5de9613a75d7d40014ffb6fc
# 3  5de9613a75d7d40014ffb6fc
# 4  5de9613a75d7d40014ffb6fc
#
#                                          xml_content template_title
# 0  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 1  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 2  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 3  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
# 4  <?xml version="1.0" encoding="utf-8"?>\n<inter...      Potential
